# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('Company_Data.csv')
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 0           17   Yes  Yes
# 1           10   Yes  Yes
# 2           12   Yes  Yes
# 3           14   Yes  Yes
# 4           13   Yes   No
# ..         ...   ...  ...
# 395         14   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes
#
# [400 rows x 11 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 0           17   Yes  Yes
# 1           10   Yes  Yes
# 2           12   Yes  Yes
# 3           14   Yes  Yes
# 4           13   Yes   No
# ..         ...   ...  ...
# 395         14   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes
#
# [400 rows x 11 columns]>

# %%
df.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# max    191.000000   80.000000   18.000000

# %%
df.isna().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# dtype: int64

# %%
df.hist()
plt.tight_layout()

# %%
df.corr()
# Out:
#                 Sales  CompPrice    Income  Advertising  Population     Price  \
# Sales        1.000000   0.064079  0.151951     0.269507    0.050471 -0.444951
# CompPrice    0.064079   1.000000 -0.080653    -0.024199   -0.094707  0.584848
# Income       0.151951  -0.080653  1.000000     0.058995   -0.007877 -0.056698
# Advertising  0.269507  -0.024199  0.058995     1.000000    0.265652  0.044537
# Population   0.050471  -0.094707 -0.007877     0.265652    1.000000 -0.012144
# Price       -0.444951   0.584848 -0.056698     0.044537   -0.012144  1.000000
# Age         -0.231815  -0.100239 -0.004670    -0.004557   -0.042663 -0.102177
# Education   -0.051955   0.025197 -0.056855    -0.033594   -0.106378  0.011747
#
#                   Age  Education
# Sales       -0.231815  -0.051955
# CompPrice   -0.100239   0.025197
# Income      -0.004670  -0.056855
# Advertising -0.004557  -0.033594
# Population  -0.042663  -0.106378
# Price       -0.102177   0.011747
# Age          1.000000   0.006488
# Education    0.006488   1.000000

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder

# %%
oe=OrdinalEncoder()
col_sel=df.select_dtypes(include='object').columns
df[col_sel]=oe.fit_transform(df[col_sel])
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120        0.0   42
# 1    11.22        111      48           16         260     83        1.0   65
# 2    10.06        113      35           10         269     80        2.0   59
# 3     7.40        117     100            4         466     97        2.0   55
# 4     4.15        141      64            3         340    128        0.0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395  12.57        138     108           17         203    128        1.0   33
# 396   6.14        139      23            3          37    120        2.0   55
# 397   7.41        162      26           12         368    159        2.0   40
# 398   5.94        100      79            7         284     95        0.0   50
# 399   9.71        134      37            0          27    120        1.0   49
#
#      Education  Urban   US
# 0           17    1.0  1.0
# 1           10    1.0  1.0
# 2           12    1.0  1.0
# 3           14    1.0  1.0
# 4           13    1.0  0.0
# ..         ...    ...  ...
# 395         14    1.0  1.0
# 396         11    0.0  1.0
# 397         18    1.0  1.0
# 398         12    1.0  1.0
# 399         16    1.0  1.0
#
# [400 rows x 11 columns]

# %%
# oe=ordinalEncoder()
#col_sel=df.select_dtypes(include='object')
#oe_col=oe.fit_transform(col_sel)
#oe_col=pd.DataFrame(oe_col)
#oe_col

# %%
# df['ShelveLoc']=oe_col[0]
# df['Urban']=oe_col[1]
# df['US']=oe_col[2]
# df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    float64
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    float64
#  10  US           400 non-null    float64
# dtypes: float64(4), int64(7)
# memory usage: 34.5 KB

# %%
df.corr()
# Out:
#                 Sales  CompPrice    Income  Advertising  Population     Price  \
# Sales        1.000000   0.064079  0.151951     0.269507    0.050471 -0.444951
# CompPrice    0.064079   1.000000 -0.080653    -0.024199   -0.094707  0.584848
# Income       0.151951  -0.080653  1.000000     0.058995   -0.007877 -0.056698
# Advertising  0.269507  -0.024199  0.058995     1.000000    0.265652  0.044537
# Population   0.050471  -0.094707 -0.007877     0.265652    1.000000 -0.012144
# Price       -0.444951   0.584848 -0.056698     0.044537   -0.012144  1.000000
# ShelveLoc    0.157470   0.023350 -0.067678     0.008544   -0.044772  0.014633
# Age         -0.231815  -0.100239 -0.004670    -0.004557   -0.042663 -0.102177
# Education   -0.051955   0.025197 -0.056855    -0.033594   -0.106378  0.011747
# Urban       -0.015419   0.066594  0.037967     0.042035   -0.052025  0.047016
# US           0.177093   0.016869  0.089601     0.684460    0.060564  0.057861
#
#              ShelveLoc       Age  Education     Urban        US
# Sales         0.157470 -0.231815  -0.051955 -0.015419  0.177093
# CompPrice     0.023350 -0.100239   0.025197  0.066594  0.016869
# Income       -0.067678 -0.004670  -0.056855  0.037967  0.089601
# Advertising   0.008544 -0.004557  -0.033594  0.042035  0.684460
# Population   -0.044772 -0.042663  -0.106378 -0.052025  0.060564
# Price         0.014633 -0.102177   0.011747  0.047016  0.057861
# ShelveLoc     1.000000  0.056488   0.001492 -0.063978 -0.039760
# Age           0.056488  1.000000   0.006488  0.028479  0.008652
# Education     0.001492  0.006488   1.000000 -0.033094 -0.078250
# Urban        -0.063978  0.028479  -0.033094  1.000000  0.047085
# US           -0.039760  0.008652  -0.078250  0.047085  1.000000

# %%
plt.rcParams['figure.figsize']=(10,5)
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df["sales"]="Bad"
df.loc[df["Sales"]>7.49,"sales"]="Good"
df.drop(["Sales"],axis=1,inplace=True)

# %%
df
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0          138      73           11         276    120        0.0   42
# 1          111      48           16         260     83        1.0   65
# 2          113      35           10         269     80        2.0   59
# 3          117     100            4         466     97        2.0   55
# 4          141      64            3         340    128        0.0   38
# ..         ...     ...          ...         ...    ...        ...  ...
# 395        138     108           17         203    128        1.0   33
# 396        139      23            3          37    120        2.0   55
# 397        162      26           12         368    159        2.0   40
# 398        100      79            7         284     95        0.0   50
# 399        134      37            0          27    120        1.0   49
#
#      Education  Urban   US sales
# 0           17    1.0  1.0  Good
# 1           10    1.0  1.0  Good
# 2           12    1.0  1.0  Good
# 3           14    1.0  1.0   Bad
# 4           13    1.0  0.0   Bad
# ..         ...    ...  ...   ...
# 395         14    1.0  1.0  Good
# 396         11    0.0  1.0   Bad
# 397         18    1.0  1.0   Bad
# 398         12    1.0  1.0   Bad
# 399         16    1.0  1.0  Good
#
# [400 rows x 11 columns]

# %%
x=df.iloc[:,0:10]
y=df.loc[:,'sales']
x
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0          138      73           11         276    120        0.0   42
# 1          111      48           16         260     83        1.0   65
# 2          113      35           10         269     80        2.0   59
# 3          117     100            4         466     97        2.0   55
# 4          141      64            3         340    128        0.0   38
# ..         ...     ...          ...         ...    ...        ...  ...
# 395        138     108           17         203    128        1.0   33
# 396        139      23            3          37    120        2.0   55
# 397        162      26           12         368    159        2.0   40
# 398        100      79            7         284     95        0.0   50
# 399        134      37            0          27    120        1.0   49
#
#      Education  Urban   US
# 0           17    1.0  1.0
# 1           10    1.0  1.0
# 2           12    1.0  1.0
# 3           14    1.0  1.0
# 4           13    1.0  0.0
# ..         ...    ...  ...
# 395         14    1.0  1.0
# 396         11    0.0  1.0
# 397         18    1.0  1.0
# 398         12    1.0  1.0
# 399         16    1.0  1.0
#
# [400 rows x 10 columns]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.7,random_state=2)

# %%
dt = DecisionTreeClassifier()
dt.fit(xtrain,ytrain)
ypred=dt.predict(xtest)

# %%
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#          Bad       0.73      0.69      0.71        64
#         Good       0.67      0.71      0.69        56
#
#     accuracy                           0.70       120
#    macro avg       0.70      0.70      0.70       120
# weighted avg       0.70      0.70      0.70       120

# %%
confusion_matrix(ytest,ypred)
# Out:
# array([[44, 20],
#        [16, 40]], dtype=int64)

# %%
dt.score(xtrain,ytrain),dt.score(xtest,ytest)
# Out:
# (1.0, 0.7)

# %%
dt.feature_importances_
# Out:
# array([0.11913278, 0.07199748, 0.12767273, 0.11344393, 0.31921604,
#        0.03753976, 0.17532536, 0.02495271, 0.01071921, 0.        ])

# %%
pd.DataFrame({'features':xtrain.columns,
             'IG':dt.feature_importances_
             }).sort_values(by='IG',ascending=False)
# Out:
#       features        IG
# 4        Price  0.319216
# 6          Age  0.175325
# 2  Advertising  0.127673
# 0    CompPrice  0.119133
# 3   Population  0.113444
# 1       Income  0.071997
# 5    ShelveLoc  0.037540
# 7    Education  0.024953
# 8        Urban  0.010719
# 9           US  0.000000

# %% [markdown]
# # Hyperparameter

# %%
params = {
    'criterion' : ['gini','entropy'],
    'splitter' : ['best','random'],
    'max_depth' :[2,3,4,6,9,12,16],
    'min_samples_split':[2,4,5,6,8,10]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV(DecisionTreeClassifier(), param_grid=params, verbose=-1)

# %%
grid.fit(xtrain,ytrain)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4, 6, 9, 12, 16],
#                          'min_samples_split': [2, 4, 5, 6, 8, 10],
#                          'splitter': ['best', 'random']},
#              verbose=-1)

# %%
grid.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 12,
#  'min_samples_split': 10,
#  'splitter': 'random'}

# %%
dt1=DecisionTreeClassifier(criterion='entropy',max_depth=9,splitter='random',min_samples_split=8)

# %%
dt1.fit(xtrain,ytrain)
ypred=dt1.predict(xtest)

# %%
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#          Bad       0.64      0.61      0.62        64
#         Good       0.58      0.61      0.59        56
#
#     accuracy                           0.61       120
#    macro avg       0.61      0.61      0.61       120
# weighted avg       0.61      0.61      0.61       120

# %%
dt1.score(xtrain,ytrain),dt1.score(xtest,ytest)
# Out:
# (0.8964285714285715, 0.6083333333333333)

# %%
dt1.feature_importances_
# Out:
# array([0.10083836, 0.09278163, 0.10809222, 0.03867713, 0.28023904,
#        0.16878782, 0.07531174, 0.01430806, 0.05305843, 0.06790556])

# %%
pd.DataFrame({'features':xtrain.columns,
              'IG':dt1.feature_importances_
             }).sort_values(by='IG',ascending=False)
# Out:
#       features        IG
# 4        Price  0.280239
# 5    ShelveLoc  0.168788
# 2  Advertising  0.108092
# 0    CompPrice  0.100838
# 1       Income  0.092782
# 6          Age  0.075312
# 9           US  0.067906
# 8        Urban  0.053058
# 3   Population  0.038677
# 7    Education  0.014308

# %%
from sklearn import tree

# %%
tree.plot_tree(dt1,feature_names=x.columns, class_names=df['sales'].unique(), filled=True)
# Out:
# [Text(0.29388297872340424, 0.95, 'ShelveLoc <= 0.789\nentropy = 1.0\nsamples = 280\nvalue = [137, 143]\nclass = Bad'),
#  Text(0.1276595744680851, 0.85, 'Income <= 95.415\nentropy = 0.84\nsamples = 67\nvalue = [49, 18]\nclass = Good'),
#  Text(0.0851063829787234, 0.75, 'Price <= 129.174\nentropy = 0.665\nsamples = 52\nvalue = [43, 9]\nclass = Good'),
#  Text(0.06382978723404255, 0.65, 'Price <= 69.914\nentropy = 0.8\nsamples = 37\nvalue = [28, 9]\nclass = Good'),
#  Text(0.0425531914893617, 0.55, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Bad'),
#  Text(0.0851063829787234, 0.55, 'Age <= 51.285\nentropy = 0.764\nsamples = 36\nvalue = [28, 8]\nclass = Good'),
#  Text(0.0425531914893617, 0.45, 'Urban <= 0.492\nentropy = 0.977\nsamples = 17\nvalue = [10, 7]\nclass = Good'),
#  Text(0.02127659574468085, 0.35, 'entropy = 0.65\nsamples = 6\nvalue = [5, 1]\nclass = Good'),
#  Text(0.06382978723404255, 0.35, 'Price <= 85.713\nentropy = 0.994\nsamples = 11\nvalue = [5, 6]\nclass = Bad'),
#  Text(0.0425531914893617, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Good'),
#  Text(0.0851063829787234, 0.25, 'Age <= 34.317\nentropy = 0.971\nsamples = 10\nvalue = [4, 6]\nclass = Bad'),
#  Text(0.06382978723404255, 0.15, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = Good'),
#  Text(0.10638297872340426, 0.15, 'entropy = 0.863\nsamples = 7\nvalue = [2, 5]\nclass = Bad'),
#  Text(0.1276595744680851, 0.45, 'Price <= 89.671\nentropy = 0.297\nsamples = 19\nvalue = [18, 1]\nclass = Good'),
#  Text(0.10638297872340426, 0.35, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Bad'),
#  Text(0.14893617021276595, 0.35, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0]\nclass = Good'),
#  Text(0.10638297872340426, 0.65, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = Good'),
#  Text(0.1702127659574468, 0.75, 'Population <= 419.448\nentropy = 0.971\nsamples = 15\nvalue = [6, 9]\nclass = Bad'),
#  Text(0.14893617021276595, 0.65, 'US <= 0.537\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]\nclass = Good'),
#  Text(0.1276595744680851, 0.55, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Good'),
#  Text(0.1702127659574468, 0.55, 'entropy = 0.918\nsamples = 6\nvalue = [2, 4]\nclass = Bad'),
#  Text(0.19148936170212766, 0.65, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Bad'),
#  Text(0.4601063829787234, 0.85, 'ShelveLoc <= 1.642\nentropy = 0.978\nsamples = 213\nvalue = [88, 125]\nclass = Bad'),
#  Text(0.2765957446808511, 0.75, 'US <= 0.111\nentropy = 0.61\nsamples = 60\nvalue = [9, 51]\nclass = Bad'),
#  Text(0.23404255319148937, 0.65, 'Income <= 64.76\nentropy = 0.918\nsamples = 18\nvalue = [6, 12]\nclass = Bad'),
#  Text(0.2127659574468085, 0.55, 'entropy = 0.918\nsamples = 6\nvalue = [4, 2]\nclass = Good'),
#  Text(0.2553191489361702, 0.55, 'Price <= 135.819\nentropy = 0.65\nsamples = 12\nvalue = [2, 10]\nclass = Bad'),
#  Text(0.23404255319148937, 0.45, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Bad'),
#  Text(0.2765957446808511, 0.45, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = Good'),
#  Text(0.3191489361702128, 0.65, 'Price <= 122.821\nentropy = 0.371\nsamples = 42\nvalue = [3, 39]\nclass = Bad'),
#  Text(0.2978723404255319, 0.55, 'entropy = 0.0\nsamples = 22\nvalue = [0, 22]\nclass = Bad'),
#  Text(0.3404255319148936, 0.55, 'Education <= 15.968\nentropy = 0.61\nsamples = 20\nvalue = [3, 17]\nclass = Bad'),
#  Text(0.3191489361702128, 0.45, 'Income <= 43.188\nentropy = 0.845\nsamples = 11\nvalue = [3, 8]\nclass = Bad'),
#  Text(0.2978723404255319, 0.35, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = Good'),
#  Text(0.3404255319148936, 0.35, 'Age <= 66.111\nentropy = 0.544\nsamples = 8\nvalue = [1, 7]\nclass = Bad'),
#  Text(0.3191489361702128, 0.25, 'entropy = 0.722\nsamples = 5\nvalue = [1, 4]\nclass = Bad'),
#  Text(0.3617021276595745, 0.25, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Bad'),
#  Text(0.3617021276595745, 0.45, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Bad'),
#  Text(0.6436170212765957, 0.75, 'Price <= 145.477\nentropy = 0.999\nsamples = 153\nvalue = [79, 74]\nclass = Good'),
#  Text(0.6223404255319149, 0.65, 'Advertising <= 0.177\nentropy = 0.998\nsamples = 140\nvalue = [66, 74]\nclass = Bad'),
#  Text(0.4574468085106383, 0.55, 'Price <= 82.843\nentropy = 0.924\nsamples = 56\nvalue = [37, 19]\nclass = Good'),
#  Text(0.43617021276595747, 0.45, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Bad'),
#  Text(0.4787234042553192, 0.45, 'CompPrice <= 129.847\nentropy = 0.848\nsamples = 51\nvalue = [37, 14]\nclass = Good'),
#  Text(0.425531914893617, 0.35, 'Urban <= 0.394\nentropy = 0.48\nsamples = 29\nvalue = [26, 3]\nclass = Good'),
#  Text(0.40425531914893614, 0.25, 'US <= 0.351\nentropy = 0.845\nsamples = 11\nvalue = [8, 3]\nclass = Good'),
#  Text(0.3829787234042553, 0.15, 'CompPrice <= 120.514\nentropy = 0.722\nsamples = 10\nvalue = [8, 2]\nclass = Good'),
#  Text(0.3617021276595745, 0.05, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Good'),
#  Text(0.40425531914893614, 0.05, 'entropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = Bad'),
#  Text(0.425531914893617, 0.15, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Bad'),
#  Text(0.44680851063829785, 0.25, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0]\nclass = Good'),
#  Text(0.5319148936170213, 0.35, 'Price <= 120.79\nentropy = 1.0\nsamples = 22\nvalue = [11, 11]\nclass = Good'),
#  Text(0.48936170212765956, 0.25, 'Urban <= 0.82\nentropy = 0.544\nsamples = 8\nvalue = [1, 7]\nclass = Bad'),
#  Text(0.46808510638297873, 0.15, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Good'),
#  Text(0.5106382978723404, 0.15, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Bad'),
#  Text(0.574468085106383, 0.25, 'Age <= 61.118\nentropy = 0.863\nsamples = 14\nvalue = [10, 4]\nclass = Good'),
#  Text(0.5531914893617021, 0.15, 'CompPrice <= 142.48\nentropy = 0.991\nsamples = 9\nvalue = [5, 4]\nclass = Good'),
#  Text(0.5319148936170213, 0.05, 'entropy = 0.863\nsamples = 7\nvalue = [5, 2]\nclass = Good'),
#  Text(0.574468085106383, 0.05, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Bad'),
#  Text(0.5957446808510638, 0.15, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Good'),
#  Text(0.7872340425531915, 0.55, 'Advertising <= 8.744\nentropy = 0.93\nsamples = 84\nvalue = [29, 55]\nclass = Bad'),
#  Text(0.6808510638297872, 0.45, 'Age <= 60.228\nentropy = 0.999\nsamples = 33\nvalue = [16, 17]\nclass = Bad'),
#  Text(0.6382978723404256, 0.35, 'CompPrice <= 118.262\nentropy = 0.918\nsamples = 18\nvalue = [6, 12]\nclass = Bad'),
#  Text(0.6170212765957447, 0.25, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Bad'),
#  Text(0.6595744680851063, 0.25, 'Income <= 26.966\nentropy = 0.985\nsamples = 14\nvalue = [6, 8]\nclass = Bad'),
#  Text(0.6382978723404256, 0.15, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Good'),
#  Text(0.6808510638297872, 0.15, 'CompPrice <= 129.424\nentropy = 0.918\nsamples = 12\nvalue = [4, 8]\nclass = Bad'),
#  Text(0.6595744680851063, 0.05, 'entropy = 1.0\nsamples = 8\nvalue = [4, 4]\nclass = Good'),
#  Text(0.7021276595744681, 0.05, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Bad'),
#  Text(0.723404255319149, 0.35, 'US <= 0.152\nentropy = 0.918\nsamples = 15\nvalue = [10, 5]\nclass = Good'),
#  Text(0.7021276595744681, 0.25, 'entropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = Bad'),
#  Text(0.7446808510638298, 0.25, 'Advertising <= 3.67\nentropy = 0.684\nsamples = 11\nvalue = [9, 2]\nclass = Good'),
#  Text(0.723404255319149, 0.15, 'entropy = 0.971\nsamples = 5\nvalue = [3, 2]\nclass = Good'),
#  Text(0.7659574468085106, 0.15, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Good'),
#  Text(0.8936170212765957, 0.45, 'Age <= 54.388\nentropy = 0.819\nsamples = 51\nvalue = [13, 38]\nclass = Bad'),
#  Text(0.851063829787234, 0.35, 'Advertising <= 14.421\nentropy = 0.605\nsamples = 27\nvalue = [4, 23]\nclass = Bad'),
#  Text(0.8297872340425532, 0.25, 'Price <= 119.13\nentropy = 0.811\nsamples = 16\nvalue = [4, 12]\nclass = Bad'),
#  Text(0.8085106382978723, 0.15, 'Advertising <= 10.327\nentropy = 0.469\nsamples = 10\nvalue = [1, 9]\nclass = Bad'),
#  Text(0.7872340425531915, 0.05, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = Good'),
#  Text(0.8297872340425532, 0.05, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Bad'),
#  Text(0.851063829787234, 0.15, 'entropy = 1.0\nsamples = 6\nvalue = [3, 3]\nclass = Good'),
#  Text(0.8723404255319149, 0.25, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = Bad'),
#  Text(0.9361702127659575, 0.35, 'Income <= 46.916\nentropy = 0.954\nsamples = 24\nvalue = [9, 15]\nclass = Bad'),
#  Text(0.9148936170212766, 0.25, 'entropy = 0.863\nsamples = 7\nvalue = [5, 2]\nclass = Good'),
#  Text(0.9574468085106383, 0.25, 'Population <= 351.165\nentropy = 0.787\nsamples = 17\nvalue = [4, 13]\nclass = Bad'),
#  Text(0.9361702127659575, 0.15, 'Price <= 125.646\nentropy = 0.946\nsamples = 11\nvalue = [4, 7]\nclass = Bad'),
#  Text(0.9148936170212766, 0.05, 'entropy = 0.544\nsamples = 8\nvalue = [1, 7]\nclass = Bad'),
#  Text(0.9574468085106383, 0.05, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Good'),
#  Text(0.9787234042553191, 0.15, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Bad'),
#  Text(0.6648936170212766, 0.65, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Good')]
